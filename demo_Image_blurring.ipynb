# %%
#Read the image:
org_img = cv2.imread("C:/ME-THESIS-TEMPLATE/IMAGE-DB/F-D-Img-1.jpg")
org_img = cv2.cvtColor(org_img,cv2.COLOR_BGR2RGB)
plt.imshow(org_img)
plt.show()

# %%
#Set the values of Mean,Variance and Sigma(Standard Deviation):
mean = 0
var = 10
sigma = var ** 0.5

# %%
#Get the shape of the image:
row,col,chal = org_img.shape
print("ROWS:",row)
print("COLUMNS:",col)
print("CHANNELS:",chal)
# Out:
# ROWS: 280
# COLUMNS: 640
# CHANNELS: 3

# %%
gaussian = np.random.normal(mean,sigma,(280,640))

# %%
#Create blank image canvas with same shape of the original image:
noisy_image = np.zeros(org_img.shape, np.float32)

# %%
if len(org_img.shape) == 2:
    noisy_image = img + gaussian
else:
    noisy_image[:, :, 0] = org_img[:, :, 0] + gaussian
    noisy_image[:, :, 1] = org_img[:, :, 1] + gaussian
    noisy_image[:, :, 2] = org_img[:, :, 2] + gaussian

# %%
#Normalize the Noisy image:
cv2.normalize(noisy_image,noisy_image,0,255,cv2.NORM_MINMAX,dtype=-1)
noisy_image = noisy_image.astype(np.int8)

# %% [markdown]
# #### IMAGE FILTERING--Gaussian Filtering:

# %%
#Display image function:
def disp_img(img):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)

# %% [markdown]
# In this approach, a Gaussian kernel is used. It is done with the function, **cv2.GaussianBlur()**. We should specify the width and height of the kernel which should be positive and odd. We also should specify the standard deviation in the X and Y directions, sigmaX and sigmaY respectively. If only sigmaX is specified, sigmaY is taken as equal to sigmaX. If both are given as zeros, they are calculated from the kernel size. **Gaussian filtering is highly effective in removing Gaussian noise from the image.**

# %%
#Importing required libraries:
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

#Read the image:
org_img = cv2.imread("C:/ME-THESIS-TEMPLATE/IMAGE-DB/F-D-Img-1.jpg")
org_img = cv2.cvtColor(org_img,cv2.COLOR_BGR2RGB)

#Filter the Image:
gauss_blur = cv2.GaussianBlur(org_img,(5,5),0)

#Plot the difference:
disp_img(org_img)
disp_img(dst_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9a09d223bcf3> in <module>
#      13
#      14 #Plot the difference:
# ---> 15 disp_img(org_img)
#      16 disp_img(dst_img)
#
# NameError: name 'disp_img' is not defined

# %% [markdown]
# #### Median Filtering:

# %% [markdown]
# Here, the function **cv2.medianBlur()** computes the median of all the pixels under the kernel window and the central pixel is replaced with this median value. This is highly effective in removing salt-and-pepper noise. One interesting thing to note is that, in the Gaussian , the filtered value for the central element can be a value which may not exist in the original image. However this is not the case in median filtering, since the central element is always replaced by some pixel value in the image. **This reduces the noise effectively.** The kernel size must be a positive odd integer.

# %%
#Importing required libraries:
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

#Read the image:
org_img = cv2.imread("C:/ME-THESIS-TEMPLATE/IMAGE-DB/F-D-Img-1.jpg")
org_img = cv2.cvtColor(org_img,cv2.COLOR_BGR2RGB)

#Filter the Image:
med_blur = cv2.medianBlur(org_img,5)

#Plot the difference:
disp_img(org_img)
disp_img(med_blur)

# %%
image_canvas = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(image_canvas)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
